# %%
# %load_ext autoreload

# %%
import os
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from monetio.models import hysplit
import cases
# Out:
# /hysplit-users/alicec/anaconda3/envs/paris/lib/python3.8/site-packages/pyresample/bilinear/__init__.py:49: UserWarning: XArray and/or zarr not found, XArrayBilinearResampler won't be available.
#   warnings.warn("XArray and/or zarr not found, XArrayBilinearResampler won't be available.")

# %%
# %autoreload
case = cases.runM()
print(case)
tag = case.vhash['tag']
tdir = case.vhash['tdir']
tname = case.vhash['tname']
configdir= case.vhash['configdir']
configfile = case.vhash['configfile']
vdir = case.vhash['vdir']
vid = case.vhash['vid']
gdir = case.vhash['gdir']
graphicstype = case.vhash['graphicstype']
vloc = case.vhash['vloc']
# Out:
# vloc : [160.587, 55.978]
# tag : M
# tdir : ../RunM/RunM_2_3_4_TFw5_12880
# tname : RunM4.nc
# configdir : ../RunM
# configfile : config.invbezyM.txt
# vdir : ../data/volcat/
# vid : v300250
# gdir : ./graphics/
# graphicstype : png

# %%
# Explore the relatinship between modeled column mass loading and concentrations
# in the column. 
# Do high column mass loading correspond to high concentrations?

# %%
# %autoreload
cdump = xr.open_dataset(os.path.join(tdir,tname))

# %%
cdump.p060
# Out:
# <xarray.DataArray 'p060' (source: 1, ens: 31, time: 36, z: 9, y: 257, x: 436)>
# [1125450288 values with dtype=float32]
# Coordinates:
#   * y          (y) int64 289 290 291 292 293 294 295 ... 540 541 542 543 544 545
#   * x          (x) int64 852 853 854 855 856 857 ... 1283 1284 1285 1286 1287
#   * time       (time) datetime64[ns] 2020-10-21T20:00:00 ... 2020-10-23T07:00:00
#   * z          (z) int64 1523 3047 4571 6095 7619 9143 10667 12191 13715
#   * ens        (ens) object 'gep01' 'gep02' 'gep03' ... 'gep29' 'gep30' 'gec00'
#   * source     (source) object 'M4'
#     latitude   (y, x) float64 ...
#     longitude  (y, x) float64 ...
# Attributes: (12/23)
#     Species ID:                   p060
#     sample time hours:            0.0
#     Starting Latitudes:           [55.978 55.978 55.978 55.978 55.978 55.978 ...
#     Starting Longitudes:          [160.587 160.587 160.587 160.587 160.587 16...
#     Starting Heights:             [3880. 4880. 3880. 3880. 3880. 3880. 3880. ...
#     Source Date:                  ['20201021.190000', '20201021.190000', '202...
#     ...                           ...
#     llcrnr latitude:              10.978001
#     Coordinate time description:  Beginning of sampling time
#     sources:                      ['102119_2880', '102119_3880', '102119_4880...
#     Method:                       lbfgsb
#     units:                        g/m3
#     MetData:                      gec00

# %%
cdump.z.values
# Out:
# array([ 1523,  3047,  4571,  6095,  7619,  9143, 10667, 12191, 13715])

# %%
# column mass loading
massload = hysplit.hysp_massload(cdump.p060)

# %%
# maximum concentration along the z dimension
concmax = cdump.p060.max(dim='z')

# %%
ens=5
tii=10
zvalues = cdump.z.values
zspace = zvalues[1]-zvalues[0]
print(zspace)
concmax.isel(ens=ens,source=0,time=tii).plot.pcolormesh(x='longitude',y='latitude')
plt.show()
massload.isel(ens=ens,source=0,time=tii).plot.pcolormesh(x='longitude',y='latitude')
plt.show()
# convert to mg
c1 = 1000* concmax.isel(ens=ens,source=0,time=tii)
m1 = 1000* massload.isel(ens=ens,source=0,time=tii)

plt.plot(c1.values.flatten(),m1.values.flatten()/zspace,'k.',MarkerSize=2)
plt.xlabel('maximum concentration in column')
plt.ylabel('column mass loading divided by thickness of one level')
plt.plot([0,5],[0,5],'--r',alpha=0.5)

plt.show()

plt.plot(c1.values.flatten(),m1.values.flatten()/1000,'k.',MarkerSize=2)
plt.xlabel('maximum concentration in column mg/m3')
plt.ylabel('column mass loading g/m2')
# Out:
# 1524
# Text(0, 0.5, 'column mass loading g/m2')

# %%
levels = np.array([0.2,2,5,10])
zspace = 1500
newlevs = levels * 1.5
newlevs
# Out:
# array([ 0.3,  3. ,  7.5, 15. ])

# %%
conc = cdump.p060

# %%
# slice the cloud vertically from bottom to top.
time_index = 10
zvalues = conc.z.values
print(zvalues)
for z in zvalues:
    temp = conc.isel(ens=1,time=time_index,source=0).sel(z=z)
    temp.plot.pcolormesh(x='longitude',y='latitude')
    plt.show()
# Out:
# [ 1523  3047  4571  6095  7619  9143 10667 12191 13715]

# %%
# look at mean value
ensmean = conc.mean(dim='ens')

# %%
# this will replace 0 values with nans.
ensmean2 = xr.where(ensmean<=0,np.nan,ensmean)

# %%
for z in [0,1,2,3,4,5,6,7.8]:
    ensmean2.isel(time=10,z=z,source=0).plot.pcolormesh(x='longitude',y='latitude')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-3ca70ec5c751> in <module>
#       1 for z in [0,1,2,3,4,5,6,7.8]:
# ----> 2     ensmean2.isel(time=10,z=z,source=0).plot.pcolormesh(x='longitude',y='latitude')
#       3     plt.show()
#
# ~/anaconda3/envs/paris/lib/python3.8/site-packages/xarray/core/dataarray.py in isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1137
#    1138         if any(is_fancy_indexer(idx) for idx in indexers.values()):
# -> 1139             ds = self._to_temp_dataset()._isel_fancy(
#    1140                 indexers, drop=drop, missing_dims=missing_dims
#    1141             )
#
# ~/anaconda3/envs/paris/lib/python3.8/site-packages/xarray/core/dataset.py in _isel_fancy(self, indexers, drop, missing_dims)
#    2272
#    2273             if name in self.xindexes:
# -> 2274                 new_var, new_index = isel_variable_and_index(
#    2275                     name, var, self.xindexes[name], var_indexers
#    2276                 )
#
# ~/anaconda3/envs/paris/lib/python3.8/site-packages/xarray/core/indexes.py in isel_variable_and_index(name, variable, index, indexers)
#     293         )
#     294
# --> 295     new_variable = variable.isel(indexers)
#     296
#     297     if new_variable.dims != (name,):
#
# ~/anaconda3/envs/paris/lib/python3.8/site-packages/xarray/core/variable.py in isel(self, indexers, missing_dims, **indexers_kwargs)
#    1133
#    1134         key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1135         return self[key]
#    1136
#    1137     def squeeze(self, dim=None):
#
# ~/anaconda3/envs/paris/lib/python3.8/site-packages/xarray/core/variable.py in __getitem__(self, key)
#     777         array `x.values` directly.
#     778         """
# --> 779         dims, indexer, new_order = self._broadcast_indexes(key)
#     780         data = as_indexable(self._data)[indexer]
#     781         if new_order:
#
# ~/anaconda3/envs/paris/lib/python3.8/site-packages/xarray/core/variable.py in _broadcast_indexes(self, key)
#     625         # key can be mapped as an OuterIndexer.
#     626         if all(not isinstance(k, Variable) for k in key):
# --> 627             return self._broadcast_indexes_outer(key)
#     628
#     629         # If all key is 1-dimensional and there are no duplicate labels,
#
# ~/anaconda3/envs/paris/lib/python3.8/site-packages/xarray/core/variable.py in _broadcast_indexes_outer(self, key)
#     699             new_key.append(k)
#     700
# --> 701         return dims, OuterIndexer(tuple(new_key)), None
#     702
#     703     def _nonzero(self):
#
# ~/anaconda3/envs/paris/lib/python3.8/site-packages/xarray/core/indexing.py in __init__(self, key)
#     419             elif isinstance(k, np.ndarray):
#     420                 if not np.issubdtype(k.dtype, np.integer):
# --> 421                     raise TypeError(
#     422                         f"invalid indexer array, does not have integer dtype: {k!r}"
#     423                     )
#
# TypeError: invalid indexer array, does not have integer dtype: array(7.8)

# %%
from utilhysplit import concutils

# %%
# slice along lines of latitude axis
latlist  = np.arange(54,56,0.2)
sns.set()
temp = ensmean.isel(time=10,source=0)
for lat in latlist:
    print(lat)
    latslice = concutils.yslice(temp,lat)
    latslice.plot.pcolormesh(x='x',y='z')
    plt.tight_layout()
    plt.show()
print(latslice.longitude)
# Out:
# 54.0
# 54.2
# 54.400000000000006
# 54.60000000000001
# 54.80000000000001
# 55.000000000000014
# 55.20000000000002
# 55.40000000000002
# 55.60000000000002
# 55.800000000000026
# <xarray.DataArray 'longitude' (x: 436)>
# array([ 155.68570709,  155.78570557,  155.88570404,  155.98570251,
#         156.08570099,  156.18569946,  156.28569794,  156.38569641,
#         156.48569489,  156.58569336,  156.68569183,  156.78569031,
#         156.88568878,  156.98568726,  157.08568573,  157.1856842 ,
#         157.28568268,  157.38568115,  157.48567963,  157.5856781 ,
#         157.68567657,  157.78567505,  157.88567352,  157.985672  ,
#         158.08567047,  158.18566895,  158.28566742,  158.38566589,
#         158.48566437,  158.58566284,  158.68566132,  158.78565979,
#         158.88565826,  158.98565674,  159.08565521,  159.18565369,
#         159.28565216,  159.38565063,  159.48564911,  159.58564758,
#         159.68564606,  159.78564453,  159.88564301,  159.98564148,
#         160.08563995,  160.18563843,  160.2856369 ,  160.38563538,
#         160.48563385,  160.58563232,  160.6856308 ,  160.78562927,
#         160.88562775,  160.98562622,  161.08562469,  161.18562317,
#         161.28562164,  161.38562012,  161.48561859,  161.58561707,
#         161.68561554,  161.78561401,  161.88561249,  161.98561096,
#         162.08560944,  162.18560791,  162.28560638,  162.38560486,
#         162.48560333,  162.58560181,  162.68560028,  162.78559875,
#         162.88559723,  162.9855957 ,  163.08559418,  163.18559265,
#         163.28559113,  163.3855896 ,  163.48558807,  163.58558655,
# ...
#        -168.71483612, -168.61483765, -168.51483917, -168.4148407 ,
#        -168.31484222, -168.21484375, -168.11484528, -168.0148468 ,
#        -167.91484833, -167.81484985, -167.71485138, -167.61485291,
#        -167.51485443, -167.41485596, -167.31485748, -167.21485901,
#        -167.11486053, -167.01486206, -166.91486359, -166.81486511,
#        -166.71486664, -166.61486816, -166.51486969, -166.41487122,
#        -166.31487274, -166.21487427, -166.11487579, -166.01487732,
#        -165.91487885, -165.81488037, -165.7148819 , -165.61488342,
#        -165.51488495, -165.41488647, -165.314888  , -165.21488953,
#        -165.11489105, -165.01489258, -164.9148941 , -164.81489563,
#        -164.71489716, -164.61489868, -164.51490021, -164.41490173,
#        -164.31490326, -164.21490479, -164.11490631, -164.01490784,
#        -163.91490936, -163.81491089, -163.71491241, -163.61491394,
#        -163.51491547, -163.41491699, -163.31491852, -163.21492004,
#        -163.11492157, -163.0149231 , -162.91492462, -162.81492615,
#        -162.71492767, -162.6149292 , -162.51493073, -162.41493225,
#        -162.31493378, -162.2149353 , -162.11493683, -162.01493835,
#        -161.91493988, -161.81494141, -161.71494293, -161.61494446,
#        -161.51494598, -161.41494751, -161.31494904, -161.21495056,
#        -161.11495209, -161.01495361, -160.91495514, -160.81495667])
# Coordinates:
#     y          int64 449
#   * x          (x) int64 852 853 854 855 856 857 ... 1283 1284 1285 1286 1287
#     time       datetime64[ns] 2020-10-22T06:00:00
#     source     <U2 'M4'
#     latitude   (x) float64 55.78 55.78 55.78 55.78 ... 55.78 55.78 55.78 55.78
#     longitude  (x) float64 155.7 155.8 155.9 156.0 ... -161.0 -160.9 -160.8
